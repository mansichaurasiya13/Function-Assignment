# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
#Solution: Here is a simple Python function that does that:


#def sum_even_numbers(numbers):
    #return sum(num for num in numbers if num % 2 == 0)


#This function uses a generator expression to iterate over the input list, selecting only the even numbers (i.e., numbers where num % 2 == 0). The sum function then adds up these even numbers.

#Here's an example usage:


#numbers = [1, 2, 3, 4, 5, 6]
#result = sum_even_numbers(numbers)
#print(result)  # Output: 12


#In this example, the even numbers in the list are 2, 4, and 6, which sum up to 12.

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
#Solution: Here is a simple Python function that reverses a string:


#def reverse_string(s):
    #return s[::-1]


#This function uses Python's slice notation to extract the characters of the string in reverse order. The [::-1] slice means "start at the end of the string and end at position 0, move with the step -1" which effectively reverses the string.

#Here's an example usage:


#original_string = "Hello, World!"
#reversed_string = reverse_string(original_string)
#print(reversed_string)  # Output: "!dlroW ,olleH"


#Alternatively, you can use the reversed function and join method to achieve the same result:


#def reverse_string(s):
    #return "".join(reversed(s))


#This function uses the reversed function to reverse the characters of the string, and then join to concatenate them into a single string.

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
#Solution: Here is a simple Python function that squares each number in a list:


#def square_numbers(numbers):
    #return [num ** 2 for num in numbers]


#This function uses a list comprehension to create a new list containing the squares of each number in the input list.

#Here's an example usage:


#numbers = [1, 2, 3, 4, 5]
#squared_numbers = square_numbers(numbers)
#print(squared_numbers)  # Output: [1, 4, 9, 16, 25]


#Alternatively, you can use the map function to achieve the same result:


#def square_numbers(numbers):
    #return list(map(lambda x: x ** 2, numbers))


#This function uses the map function to apply a lambda function (which squares each number) to each element in the input list, and then converts the result to a list.

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
#Solution: Here is a Python function that checks if a number is prime:


#def is_prime(n):
    #if n <= 1:
        #return False
    #for i in range(2, int(n**0.5) + 1):
        #if n % i == 0:
            #return False
    #return True

# Check prime numbers from 1 to 200
#for num in range(1, 201):
    #if is_prime(num):
        #print(f"{num} is a prime number")


#This function works by checking if a number n is divisible by any number from 2 to the square root of n. If it is, then n is not a prime number. Otherwise, it is a prime number.

#The reason we only need to check up to the square root of n is that a larger factor of n would be a multiple of a smaller factor that has already been checked.

#Note: This function uses a trial division method, which is not the most efficient way to check for primality, especially for large numbers. For a more efficient approach, you can use the Miller-Rabin primality test.

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
#Solution: Here is an example of an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms:


#class FibonacciIterator:
    #def __init__(self, n):
        #self.n = n
        #self.a, self.b = 0, 1
        #self.count = 0

    #def __iter__(self):
        #return self

    #def __next__(self):
        #if self.count < self.n:
            #result = self.a
            #self.a, self.b = self.b, self.a + self.b
            #self.count += 1
            #return result
        #else:
            #raise StopIteration


# Example usage:
#fib_iterator = FibonacciIterator(10)
#for num in fib_iterator:
    #print(num)


#This FibonacciIterator class takes an integer n in its constructor, which specifies the number of terms in the Fibonacci sequence to generate. The __iter__ method returns the iterator object itself, and the __next__ method generates the next number in the sequence.

#In the example usage, we create a FibonacciIterator object with n=10 and iterate over it using a for loop, printing each number in the sequence.

#Note: This implementation uses an iterative approach to generate the Fibonacci sequence, which is more memory-efficient than a recursive approach for large values of n.

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
#Solution: Here is a simple generator function in Python that yields the powers of 2 up to a given exponent:


#def powers_of_two(exponent):
    #for i in range(exponent + 1):
        #yield 2 ** i

# Example usage:
#for power in powers_of_two(5):
    #print(power)


#This powers_of_two generator function takes an integer exponent as input and yields the powers of 2 from 2^0 to 2^exponent.

#In the example usage, we iterate over the generator using a for loop and print each power of 2.

#Alternatively, you can use a generator expression to achieve the same result:


#powers_of_two = (2 ** i for i in range(exponent + 1))


#This generator expression uses a similar approach to the generator function, but in a more concise form.

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
#Solution: Here is a simple generator function that reads a file line by line and yields each line as a string:


#def read_file_lines(file_path):
    #with open(file_path, 'r') as file:
        #for line in file:
            #yield line.strip()

# Example usage:
#file_path = 'example.txt'
#for line in read_file_lines(file_path):
    #print(line)


#This read_file_lines generator function takes a file path as input, opens the file in read mode, and iterates over each line in the file. The yield statement returns each line as a string, stripped of any leading or trailing whitespace.

#In the example usage, we iterate over the generator using a for loop and print each line.

#Note: The with statement ensures that the file is properly closed after reading, regardless of whether an exception is thrown or not.

#Alternatively, you can use a generator expression to achieve the same result:


#read_file_lines = (line.strip() for line in open(file_path, 'r'))


#This generator expression uses a similar approach to the generator function, but in a more concise form. However, be aware that this approach does not ensure proper file closure.

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
#Solution: Here is an example of using a lambda function to sort a list of tuples based on the second element of each tuple:


# Define a list of tuples
#tuples_list = [(1, 3), (2, 1), (3, 2), (4, 4)]

# Sort the list using a lambda function as the sorting key
#sorted_list = sorted(tuples_list, key=lambda x: x[1])

# Print the sorted list
#print(sorted_list)


#In this example, the lambda function lambda x: x[1] takes a tuple x and returns its second element x[1]. The sorted function uses this lambda function as the sorting key to sort the list of tuples based on the second element of each tuple.

#Output:


#[(2, 1), (3, 2), (1, 3), (4, 4)]


#Note: The sorted function returns a new sorted list and does not modify the original list. If you want to sort the original list in-place, you can use the list.sort method instead:


#tuples_list.sort(key=lambda x: x[1])

# %%
#9. Write a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit
#Solution: Here is a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit:


# Define a function to convert Celsius to Fahrenheit
#def celsius_to_fahrenheit(celsius):
    #return (celsius * 9/5) + 32

# Define a list of temperatures in Celsius
#celsius_temperatures = [0, 10, 20, 30, 40]

# Use map() to convert the list of temperatures to Fahrenheit
#fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Print the converted temperatures
#print(fahrenheit_temperatures)


#In this program, the celsius_to_fahrenheit function takes a temperature in Celsius as input and returns the equivalent temperature in Fahrenheit. The map() function applies this conversion function to each element in the celsius_temperatures list, returning a new list with the converted temperatures.

#Output:


#[32.0, 50.0, 68.0, 86.0, 104.0]


#Note: The map() function returns a map object, so we need to convert it to a list using the list() function to get the resulting list of Fahrenheit temperatures.

# %%
#10. Create a Python program that uses filter() to remove all the vowels from a given string.
#Solution: Here is a Python program that uses filter() to remove all the vowels from a given string:


# Define a function to check if a character is not a vowel
#def is_not_vowel(char):
    #vowels = 'aeiouAEIOU'
    #return char not in vowels

# Define a string
#input_string = "Hello World"

# Use filter() to remove vowels from the string
#result_string = ''.join(filter(is_not_vowel, input_string))

# Print the resulting string
#print(result_string)


#In this program, the is_not_vowel function takes a character as input and returns True if it is not a vowel, and False otherwise. The filter() function applies this function to each character in the input_string, returning a new string with only the non-vowel characters.

#Output:


#Hll Wrld


#Note: The filter() function returns a filter object, so we need to use the join() function to concatenate the characters into a single string.

#Alternatively, you can use a lambda function to make the code more concise:


#result_string = ''.join(filter(lambda char: char not in 'aeiouAEIOU', input_string))

# %%
#11.Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

#Order Number	Book Title and Author	Quantity	Price per Item
#34587	Learning Python, Mark Lutz	4	40.95
#98762	Programming Python, Mark Lutz	5	56.80
#77226	Head First Python, Paul Barry	3	32.95
#88112	Einführung in Python3, Bernd Klein	3	24.99

#Write a Python program, which returns a list with 2-tuples. Each tuple consists of a the order number and the product of the price per items and the quantity. The product should be increased by 10,- € if the value of the order is less than 100,00 €.
#Write a Python program using lambda and map.

#Solution: orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95],["98762", "Programming Python, Mark Lutz", 5, 56.80],["77226", "Head First Python, Paul Barry", 3,32.95],["88112", "Einführung in Python3, Bernd Klein", 	3, 24.99]]

#invoice_totals = list(map(lambda x: x if x[1] >= min_order else (x[0], x[1] + 10),map(lambda x: (x[0],x[2] * x[3]), orders)))

#Note- To understand the working of above lambda function break the function till innermost map function. Break and understand in below fashion
#output1 = map(lambda x: (x[0],x[2] * x[3]), orders) #Innermost lambda function execution

#output2 = map(lambda x: x if x[1] >= min_order else (x[0], x[1] + 10),map(lambda x: (x[0],x[2] * x[3]), orders))

#final = list(map(lambda x: x if x[1] >= min_order else (x[0], x[1] + 10),map(lambda x: (x[0],x[2] * x[3]), orders)))
#This program first extracts the order numbers, quantities, and prices from the accounting routine. Then, it uses map and a lambda function to calculate the product of the price and quantity for each order. If the product is less than $100, it adds $10 to the result. Finally, it prints the list of 2-tuples, where each tuple contains the order number and the calculated product.
